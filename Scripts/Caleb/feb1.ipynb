# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

from calibrationFunctions import openFiles, calculateForce, calculateTetherExtension, findTetheredBeads

# %% [markdown]
# # February 1st
# ## 1 pm
# ### 1

# %%
folderPath = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\1 pM\1\DataTSV"

dataFrame = openFiles(folderPath, numRef=2, numExp=5, fps=400) # 7 total beads

ref = dataFrame["zRefBead1"]
exp = dataFrame["zExpBead5"]

plt.plot(dataFrame["linearMotor"][30000:50000], color="#b30000")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Distance (mm)"); plt.title("Linear Motor")
plt.show()

lowForceStart = 30000
lowForceEnd = 50000

plt.plot(exp[30000:50000] - ref[30000:50000])
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\1 pM\1\DataTSV

# %% [markdown]
# ### 2

# %%
folderPath = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\1 pM\2\DataTSV"

dataFrame = openFiles(folderPath, numRef=1, numExp=9, fps=400) # 10 total beads

ref = dataFrame["zRefBead1"]
exp = dataFrame["zExpBead5"]

plt.plot(dataFrame["linearMotor"][:260000], color="#b30000")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Distance (mm)"); plt.title("Linear Motor")
plt.show()

lowForceStart = 25000
lowForceEnd = 50000

glassPosition = -1150
window_width = 50

extension = exp - ref - glassPosition

cumsum_vec = np.cumsum(np.insert(extension, 0, 0)) 
smoothExtension = (cumsum_vec[window_width:] - cumsum_vec[:-window_width]) / window_width


# plt.plot(exp[lowForceStart:lowForceEnd] - ref[lowForceStart:lowForceEnd])
# plt.axhline(glassPosition)
# plt.show()

# plt.hist(exp[lowForceStart:lowForceEnd] - ref[lowForceStart:lowForceEnd], bins = 100)
# plt.axvline(glassPosition)
# plt.show()

plt.plot(extension[:260000], label="400 fps", color="#adebad")
plt.plot(smoothExtension[:260000], label="1/8s smooth", color="#145214")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)"); plt.title("1st attempt")
plt.legend()
plt.show()
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\1 pM\2\DataTSV

# %%
plt.plot(dataFrame["rotationalMotor"][280000:300000]/360, color="#000099")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Number of turns"); plt.title("Rotational Motor")
plt.show()


plt.plot(extension[280000:300000], color="#adebad")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)"); plt.title("2nd attempt multi-tether")
plt.show()

# %% [markdown]
# ### 3

# %%
folderPath = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\1 pM\3\DataTSV"

dataFrame = openFiles(folderPath, numRef=1, numExp=12, fps=400) # 13 total beads

ref = dataFrame["zRefBead1"]
exp = dataFrame["zExpBead1"]

plt.plot(dataFrame["linearMotor"], color="#b30000")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Distance (mm)"); plt.title("Linear Motor")
plt.show()

lowForceStart = 20000
lowForceEnd = 30000

glassPosition = -525
window_width = 50

extension = exp - ref - glassPosition

cumsum_vec = np.cumsum(np.insert(extension, 0, 0)) 
smoothExtension = (cumsum_vec[window_width:] - cumsum_vec[:-window_width]) / window_width


# plt.plot(exp[lowForceStart:lowForceEnd] - ref[lowForceStart:lowForceEnd])
# plt.axhline(glassPosition)
# plt.show()

# plt.hist(exp[lowForceStart:lowForceEnd] - ref[lowForceStart:lowForceEnd], bins = 100);
# plt.axvline(glassPosition)
# plt.show(

plt.plot(extension[:260000], label="400 fps", color="#adebad")
plt.plot(smoothExtension[:260000], label="1/8s smooth", color="#145214")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)"); plt.title("2nd attempt")
plt.legend()
plt.show()
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\1 pM\3\DataTSV

# %%
plt.plot(dataFrame["rotationalMotor"][350000:660000], color="#000099")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Number of turns"); plt.title("Rotational Motor")
plt.show()

plt.plot(extension[350000:660000], color="#adebad")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)"); plt.title("2nd attempt multi-tether")
plt.show()

# %% [markdown]
# ## 100 fM
# ### 1

# %%
folderPath = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\100 fM\1\DataTSV"

dataFrame = openFiles(folderPath, numRef=3, numExp=3, fps=400) # 6 total beads

ref = dataFrame["zRefBead3"]
exp = dataFrame["zExpBead2"]

plt.plot(dataFrame["linearMotor"][40000:260000], color="#b30000")
plt.xlabel("Frame # (400fps)"); plt.ylabel("Distance (mm)"); plt.title("Linear Motor")
plt.show()

lowForceStart = 40000
lowForceEnd = 55000

plt.plot(dataFrame["zExpBead1"][40000:260000] - ref[40000:260000])
plt.plot(dataFrame["zExpBead2"][40000:260000] - ref[40000:260000])
plt.plot(dataFrame["zExpBead3"][40000:260000] - ref[40000:260000])
plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)"); plt.title("Bead comparision")
plt.show()
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\100 fM\1\DataTSV

# %% [markdown]
# ### 2

# %%
folderPath = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\100 fM\2\DataTSV"

dataFrame = openFiles(folderPath, numRef=1, numExp=9, fps=400) # 10 total beads

ref = dataFrame["zExpBead7"]
exp = dataFrame["zExpBead3"]

# plt.plot(dataFrame["linearMotor"][:3500])
# plt.show()

lowForceStart = 0
lowForceEnd = 3500

plt.plot(dataFrame["zExpBead1"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead2"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead3"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead4"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead5"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead6"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead8"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zExpBead9"][:lowForceEnd] - ref[:lowForceEnd])
plt.plot(dataFrame["zRefBead1"][:lowForceEnd] - ref[:lowForceEnd])
plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)"); plt.title("Bead comparision")
plt.show()
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\February\1\100 fM\2\DataTSV
