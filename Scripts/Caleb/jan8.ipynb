# %%
from calibrationFunctions import openFiles, calculateForce, calculateTetherExtension, findTetheredBeads
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Test 1

# %%
folderPath1 = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\January\8\Test1\DataTSV"

dataFrame1 = openFiles(folderPath1, numRef=3, numExp=7, fps=400)
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\January\8\Test1\DataTSV

# %%
plt.plot(dataFrame1["linearMotor"])
plt.title("Linear Motor"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Distance (nm)");
plt.show()

lowStart = 21000
lowEnd = 39000

refBead = dataFrame1["zRefBead1"]
bead1 = dataFrame1["zExpBead1"]
bead2 = dataFrame1["zExpBead2"]
bead3 = dataFrame1["zExpBead3"]
bead4 = dataFrame1["zExpBead4"]
bead5 = dataFrame1["zExpBead5"]
bead6 = dataFrame1["zExpBead6"]
bead7 = dataFrame1["zExpBead7"]

plt.plot(bead1 - refBead +1000, color="#1a75ff") # weird
plt.plot(bead2 - refBead + 900, color="#ff9933") # Bad
plt.plot(bead3 - refBead + 700, color="#33cc33")
plt.plot(bead4 - refBead + 600, color="#e62e00") # Best
plt.plot(bead5 - refBead + 400, color="#a64dff")
plt.plot(bead6 - refBead + 200, color="#ac7339")
plt.plot(bead7 - refBead, color="#ff80bf") # Bad
plt.title("Comparision of Beads"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

# %% [markdown]
# #### Bead 1

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead1"]

glassPosition = -38

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#1a75ff")
plt.title("Bead 1"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#003380");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 2

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead2"]

glassPosition = -38

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#ff9933")
plt.title("Bead 2"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#cc6600");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 3

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead3"]

glassPosition = -70

plt.plot(ref[lowStart:250000] - exp[lowStart:260000] - glassPosition, color="#33cc33")
plt.title("Bead 3"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(ref[lowStart:lowEnd] - exp[lowStart:lowEnd], bins=100, color="#196619");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 4

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead4"]

glassPosition = -30

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#e62e00")
plt.title("Bead 4"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#801a00");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 5

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead5"]

glassPosition = 7

plt.plot(ref[lowStart:250000] - exp[lowStart:260000] - glassPosition, color="#a64dff")
plt.title("Bead 5"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(ref[lowStart:lowEnd] - exp[lowStart:lowEnd], bins=100, color="#400080");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 6

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead6"]

glassPosition = -44

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#ac7339")
plt.title("Bead 6"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#4d3319");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 7

# %%
ref = dataFrame1["zRefBead1"]
exp = dataFrame1["zExpBead7"]

glassPosition = 3

plt.plot(ref[lowStart:250000] - exp[lowStart:260000] - glassPosition, color="#ff80bf")
plt.title("Bead 7"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(ref[lowStart:lowEnd] - exp[lowStart:lowEnd], bins=100, color="#800040");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# # Test 2

# %%
folderPath2 = r"C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\January\8\Test2\DataTSV"

dataFrame2 = openFiles(folderPath2, numRef=3, numExp=9, fps=400)
# Out:
# Using: C:\Users\Perkins Lab\Desktop\Caleb Maddry\Data\2025\January\8\Test2\DataTSV

# %%
lowStart = 38000
lowEnd = 62000

highStart = 73000
highEnd = 83000

plt.plot(dataFrame2["linearMotor"][:260000])
plt.title("Linear Motor"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Distance (nm)");
plt.show()

start = lowStart
stop = 83000

refBead = dataFrame2["zRefBead2"][start:stop]
bead1 = dataFrame2["zExpBead1"][start:stop]
bead2 = dataFrame2["zExpBead2"][start:stop]
bead3 = dataFrame2["zExpBead3"][start:stop]
bead4 = dataFrame2["zExpBead4"][start:stop]
bead5 = dataFrame2["zExpBead5"][start:stop]
bead6 = dataFrame2["zExpBead6"][start:stop]
bead7 = dataFrame2["zExpBead7"][start:stop]
bead8 = dataFrame2["zExpBead8"][start:stop]

plt.plot(bead1 - refBead +1000, color="#1a75ff") # weird
plt.plot(bead2 - refBead + 800, color="#ff9933") # Bad
plt.plot(bead3 - refBead + 700, color="#33cc33")
plt.plot(bead4 - refBead + 400, color="#e62e00") # Best
plt.plot(bead5 - refBead + 300, color="#a64dff")
plt.plot(bead6 - refBead + 150, color="#ac7339")
plt.plot(bead7 - refBead, color="#ff80bf") # Bad
plt.plot(bead8 - refBead -100, color="#a3a375") # Bad
plt.title("Comparision of Beads"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

# %% [markdown]
# #### Bead 1

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead1"]

glassPosition = -42

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#1a75ff")
plt.title("Bead 1"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#003380");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 2

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead2"]

glassPosition = -35

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#ff9933")
plt.title("Bead 2"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#cc6600");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 3

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead3"]

glassPosition = -42

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#33cc33")
plt.title("Bead 3"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#196619");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 4

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead4"]

glassPosition = -125

plt.plot(ref[lowStart:250000] - exp[lowStart:260000] - glassPosition, color="#e62e00")
plt.title("Bead 4"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(ref[lowStart:lowEnd] - exp[lowStart:lowEnd], bins=100, color="#801a00");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 5

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead5"]

glassPosition = -30

plt.plot(ref[lowStart:250000] - exp[lowStart:260000] - glassPosition, color="#a64dff")
plt.title("Bead 5"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(ref[lowStart:lowEnd] - exp[lowStart:lowEnd], bins=100, color="#400080");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 6

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead6"]

glassPosition = -10

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#ac7339")
plt.title("Bead 6"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#4d3319");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 7

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead7"]

glassPosition = -10

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#ff80bf")
plt.title("Bead 7"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#800040");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()

# %% [markdown]
# #### Bead 8

# %%
ref = dataFrame2["zRefBead1"]
exp = dataFrame2["zExpBead8"]

glassPosition = -10

plt.plot(exp[lowStart:260000] - ref[lowStart:250000] - glassPosition, color="#a3a375")
plt.title("Bead 8"); plt.xlabel("Frame # (400fps)"); plt.ylabel("Extension (nm)");
plt.show()

plt.hist(exp[lowStart:lowEnd] - ref[lowStart:lowEnd], bins=100, color="#3d3d29");
plt.axvline(glassPosition, color="red")
plt.xlabel("nm"); plt.ylabel("Count");
plt.show()
