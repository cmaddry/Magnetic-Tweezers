# %%
from calibrationFunctions import openFiles, calculateForce, calculateTetherExtension, findTetheredBeads

# %%
folderPath = "C:\\Users\\maddr\\OneDrive\\Documents\\MTCode\\Magnetic-Tweezers\\Data\\December\\19\\arnulfMT"

dataFrame = openFiles(folderPath, numRef=0, numExp=3, fps=400);
# Out:
# Using: C:\Users\maddr\OneDrive\Documents\MTCode\Magnetic-Tweezers\Data\December\19\arnulfMT

# %%
# lowForce = []

# for index in dataFrame.itertuples():
#     if dataFrame['linearMotor'][index[0]] <= 15: lowForce = lowForce + [index[0]]
#     if index[0] % 50000 == 0: print("Finding the low force points")

# %%
# lowForceIdx = [min(lowForce), max(lowForce)]

# tetherBeads = findTetheredBeads(dataFrame, lowForceIdx);
# dataFrame = calculateTetherExtension(dataFrame, tetherBeads, lowForceIdx);
# forcePSD, forceAV, forceEPT = calculateForce(dataFrame, tetherBeads, lowForceIdx, 400, 1400)

# print("Force using PSD:", forcePSD[0]);print("Force using AV:", forceAV[0]);print("Force using EPT:", forceEPT[0]);

# %%
import matplotlib.pyplot as plt
import numpy as np

highForceStart = 0;
highForceEnd = 24000;

medForceStart = 27200
medForceEnd = 40000

lowForceStart = 50000
lowForceEnd = 90000

forceExtStart =90000
forceExtEnd = 11

plt.plot(dataFrame["linearMotor"][100000:]);

# %%
dataFrame["zExpBead1"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 287995   NaN
# 287996   NaN
# 287997   NaN
# 287998   NaN
# 287999   NaN
# Name: zExpBead1, Length: 288000, dtype: float64
