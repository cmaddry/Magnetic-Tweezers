# %%
from calibrationFunctions import openFiles, calculateForce, calculateTetherExtension, findTetheredBeads

# %%
folderPath = "C:\\Users\\maddr\\OneDrive\\Documents\\MTCode\\Magnetic-Tweezers\\Data\\December\\19\\ArnulfPS"

dataFrame = openFiles(folderPath, numRef=3, numExp=1, fps=400);
# Out:
# Using: C:\Users\maddr\OneDrive\Documents\MTCode\Magnetic-Tweezers\Data\December\19\ArnulfPS

# %%
import matplotlib.pyplot as plt
import numpy as np

xData1 = dataFrame["xRefBead3"]
xData2 = dataFrame["xRefBead2"]

yData1 = dataFrame["yRefBead3"]
yData2 = dataFrame["yRefBead2"]

zData1 = dataFrame["zRefBead3"]
zData2 = dataFrame["zRefBead2"]

startIdx = 65000
endIdx = 95000


# plt.hist(-zData2[startIdx:endIdx] + 4360, 100);
# plt.axvline(x=0)


zData2 = -zData2[startIdx:endIdx] + 4360


plt.plot(zData2)

# %%
import matplotlib.pyplot as plt

xData1 = dataFrame["xRefBead3"]
xData2 = dataFrame["xRefBead2"]

yData1 = dataFrame["yRefBead3"]
yData2 = dataFrame["yRefBead2"]

zData1 = dataFrame["zRefBead3"]
zData2 = dataFrame["zRefBead2"]


plt.plot(zData2[60000:100000])



# highForceStart = 0;
# highForceEnd = 7400;

# medForceStart = 11000
# medForceEnd = 27000

# lowForceStart = 57000
# lowForceEnd = 88000
